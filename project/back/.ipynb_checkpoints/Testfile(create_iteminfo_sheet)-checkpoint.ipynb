# %%
from flask import Flask, request, jsonify
import psycopg2 as pg
import os
from PIL import Image
import json

# %%
conn = pg.connect(host="127.0.0.1", dbname="youreco", user="postgres", password="postgres", port=5432)
cur = conn.cursor()

# %%
section_list = [(1, 'D8mq5L9R0GM', 0, 300, 385002, [8493, 8517, 8559, 8629]), (2, 'D8mq5L9R0GM', 300, 600, 445726, [13784, 21765, 21250, 21284]), (3, 'D8mq5L9R0GM', 600, 918, 119561, [9073, 11887, 18761, 24267])]

# %%
section_list
# Out:
# [(1, 'D8mq5L9R0GM', 0, 300, 385002, [8493, 8517, 8559, 8629]),
#  (2, 'D8mq5L9R0GM', 300, 600, 445726, [13784, 21765, 21250, 21284]),
#  (3, 'D8mq5L9R0GM', 600, 918, 119561, [9073, 11887, 18761, 24267])]

# %% [markdown]
# ## Get Full Recommendation List(with Item Code)

# %%
def get_recommendation(cateID):
    # communicate with rec server
    return [[8493, 8517, 8559, 8629],[8493, 8517, 8559, 8629],[8493, 8517, 8559, 8629]]

# %% [markdown]
# ## replace itemcode table to itemdata sheet

# %%
#get iteminfo list from itemid
def item_id_to_info(itemid):
    cur.execute("select * from iteminfo where itemid = {0};".format(itemid))
    res = cur.fetchone()
    item_name = res[1]
    item_category = res[2]
    item_price = res[3]
    image_filename = res[7]
    with open("./data/{0}/{1}.jpg".format(item_category,"c333e61ace13"), "rb") as image_file:
        image_binary = image_file.read()
        encoded_image = base64.b64encode(image_binary)
    item_link = "https://www.naver.com"
    return [item_name, item_price, image_binary, item_link]

# %%
#create itemdata sheet
def create_section_object(start_time, end_time, category):
    rec_dict = {
        "start_time":start_time, 
        "end_time":end_time, 
        "category": category, 
        "sim_item":[], 
        "rel_item_01" : [], 
        "rel_item_02" : [], 
        "rel_item_03" : []
    }
    
    return rec_dict

# %%
#full sheet that send to frontend page
new_section_list = []

# %%
for section in section_list:
    new_section = create_section_object(section[2], section[3], section[4]);
    rel_item_list = get_recommendation(new_section["category"])
    rel_item_01_code = rel_item_list[0]
    rel_item_02_code = rel_item_list[1]
    rel_item_03_code = rel_item_list[2]
    
    #sim_item
    for each_item in section[5]:
        item = item_id_to_info(each_item)
        new_section["sim_item"].append(item)
    
    #rel_item_01
    for each_item in rel_item_01_code:
        item = item_id_to_info(each_item)
        new_section["rel_item_01"].append(item)
    
    #rel_item_02
    for each_item in rel_item_02_code:
        item = item_id_to_info(each_item)
        new_section["rel_item_02"].append(item)
    
    #rel_item_03
    for each_item in rel_item_03_code:
        item = item_id_to_info(each_item)
        new_section["rel_item_03"].append(item)
        
        
    new_section_list.append(new_section)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 10
#       8 #sim_item
#       9 for each_item in section[5]:
# ---> 10     item = item_id_to_info(each_item)
#      11     new_section["sim_item"].append(item)
#      13 #rel_item_01
#
# Cell In[6], line 9, in item_id_to_info(itemid)
#       7 item_price = res[3]
#       8 image_filename = res[7]
# ----> 9 with open("./data/{0}/{1}".format(item_category,image_filename), "rb") as image_file:
#      10     image_binary = image_file.read()
#      11     encoded_image = base64.b64encode(image_binary)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/118920/c333e61ace13'

# %%
new_section_list
# Out:
# [{'start_time': 0,
#   'end_time': 300,
#   'category': 385002,
#   'sim_item': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_01': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_02': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_03': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']]},
#  {'start_time': 300,
#   'end_time': 600,
#   'category': 445726,
#   'sim_item': [['펫트리움 코지 고양이 수직 스크래쳐 월 타워 중대형, 1개',
#     19810,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '227d42fdfeee'],
#    ['펫 스테이 투명해먹 캣타워, 1개, 브라운',
#     88000,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '081939ab2728'],
#    ['가또블랑코 고양이 피타 스크래쳐 타워, 혼합색상, 1개',
#     64500,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '8d66ea99691b'],
#    ['네츄럴프로 하늘정원 큐티 캣타워, 173 베이지, 1개',
#     42900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'ec85a9c891cc']],
#   'rel_item_01': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_02': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_03': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']]},
#  {'start_time': 600,
#   'end_time': 918,
#   'category': 119561,
#   'sim_item': [['요기펫 방 앤 화장실용 견문2 안전문, WHITE',
#     15000,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '0a1792506c4e'],
#    ['브라더펫 강아지 화장실 배변판, 1개, 핑크그레이',
#     24000,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'ce0574d6df5c'],
#    ['LG생활건강 LG유니참 데오토일렛 고양이 화장실 특대형 (와이드), 선택완료, 선택완료',
#     81240,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '3b64681b2ec6'],
#    ['딩동펫 반려동물 바스켓 특대형 고양이 화장실, 옐로우',
#     19800,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '52e6c7cb98c9']],
#   'rel_item_01': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_02': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']],
#   'rel_item_03': [['레드퍼피 반려견 잉클 원 방석, 부비베어',
#     13600,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'c333e61ace13'],
#    ['크림펫 반려동물 극세사 마약 방석, 핑크',
#     16680,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'a550afe1f6b4'],
#    ['레드퍼피 반려견 스넉워머 원 방석, 아이보리',
#     20900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     '6a84193d7833'],
#    ['포글 반려동물 사계절 강아지 방석 허그 쿠션, 클리어민트',
#     36900,
#     <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x675>,
#     'https://www.naver.com',
#     'f80b752a10c7']]}]

# %%
json_val = json.dumps(new_section_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 json_val = json.dumps(new_section_list)
#
# File ~\AppData\Local\anaconda3\Lib\json\__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~\AppData\Local\anaconda3\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~\AppData\Local\anaconda3\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~\AppData\Local\anaconda3\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type JpegImageFile is not JSON serializable
