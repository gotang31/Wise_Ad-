# %% [markdown]
# # Environment Setup

# %%
# !pip install -i https://test.pypi.org/simple/ supervision==0.3.0
# !pip install -q transformers
# !pip install -q pytorch-lightning
# !pip install -q timm
#!pip install -q roboflow
# !pip install wandb
# !pip install albumentations
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: supervision==0.3.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.20.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from supervision==0.3.0) (1.26.2)
# Requirement already satisfied: opencv-python in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from supervision==0.3.0) (4.8.1.78)
# Requirement already satisfied: matplotlib in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from supervision==0.3.0) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from matplotlib->supervision==0.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->supervision==0.3.0) (1.16.0)
# Requirement already satisfied: wandb in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (3.1.40)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (5.9.7)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (1.39.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (68.2.2)
# Requirement already satisfied: appdirs>=1.4.3 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from wandb) (4.25.1)
# Requirement already satisfied: six>=1.4.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2023.11.17)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting albumentations
#   Downloading albumentations-1.3.1-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy>=1.11.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from albumentations) (1.26.2)
# Requirement already satisfied: scipy>=1.1.0 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from albumentations) (1.11.4)
# Collecting scikit-image>=0.16.1 (from albumentations)
#   Downloading scikit_image-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from albumentations) (6.0.1)
# Collecting qudida>=0.0.4 (from albumentations)
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python-headless>=4.1.1 (from albumentations)
#   Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting scikit-learn>=0.19.1 (from qudida>=0.0.4->albumentations)
#   Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from qudida>=0.0.4->albumentations) (4.7.1)
# Requirement already satisfied: networkx>=2.8 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (10.0.1)
# Collecting imageio>=2.27 (from scikit-image>=0.16.1->albumentations)
#   Downloading imageio-2.33.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.16.1->albumentations)
#   Downloading tifffile-2023.12.9-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (23.1)
# Collecting lazy_loader>=0.3 (from scikit-image>=0.16.1->albumentations)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting joblib>=1.1.1 (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading albumentations-1.3.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 10.1 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 42.8 MB/s eta 0:00:0000:0100:01
# Downloading scikit_image-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 49.9 MB/s eta 0:00:0000:0100:01
# Downloading imageio-2.33.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 19.3 MB/s eta 0:00:00
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 26.6 MB/s eta 0:00:0000:010:01
# Downloading tifffile-2023.12.9-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 20.0 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 22.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: tifffile, threadpoolctl, opencv-python-headless, lazy_loader, joblib, imageio, scikit-learn, scikit-image, qudida, albumentations
# Successfully installed albumentations-1.3.1 imageio-2.33.1 joblib-1.3.2 lazy_loader-0.3 opencv-python-headless-4.8.1.78 qudida-0.0.4 scikit-image-0.22.0 scikit-learn-1.3.2 threadpoolctl-3.2.0 tifffile-2023.12.9

# %%
import torch
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)

#import roboflow
import supervision
import transformers
import pytorch_lightning

print(
#    "roboflow:", roboflow.__version__, 
    "; supervision:", supervision.__version__, 
    "; transformers:", transformers.__version__, 
    "; pytorch_lightning:", pytorch_lightning.__version__
)
# Out:
# /bin/bash: line 1: nvcc: command not found
# torch:  2.1 ; cuda:  2.1.2
# ; supervision: 0.3.0 ; transformers: 4.36.1 ; pytorch_lightning: 2.1.2

# %% [markdown]
# # Load Model

# %%
# Huggingface 모델 라이브러리에서 pretrained image_processor & model 불러오기
import torch
from transformers import DetrForObjectDetection, DetrImageProcessor


# settings
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
CHECKPOINT = 'facebook/detr-resnet-50'


image_processor = DetrImageProcessor.from_pretrained(CHECKPOINT)
model = DetrForObjectDetection.from_pretrained(CHECKPOINT)
# Out:
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Create COCO data loaders

# %%
import os
import torchvision


# settings
dataset_location = f"/mnt/d/Data/final/dataset"
ANNOTATION_FILE_NAME = "labels.json"
TRAIN_DIRECTORY = os.path.join(dataset_location, "train")
VAL_DIRECTORY = os.path.join(dataset_location, "val")
TEST_DIRECTORY = os.path.join(dataset_location, "test")


class CocoDetection(torchvision.datasets.CocoDetection):
    def __init__(
        self,
        dataset_directory_path: str,    # lables.json 파일 data폴더 외부에 존재할 경우 사용
        image_directory_path: str,  # lables.json 파일 data폴더 내부에 존재할 경우 사용
        image_processor,
        train: bool = True
    ):
        annotation_file_path = os.path.join(image_directory_path, ANNOTATION_FILE_NAME) # labels.json 파일 디렉토리
        super(CocoDetection, self).__init__(image_directory_path, annotation_file_path)
        self.image_processor = image_processor

    def __getitem__(self, idx):
        images, annotations = super(CocoDetection, self).__getitem__(idx)
        image_id = self.ids[idx]
        annotations = {'image_id': image_id, 'annotations': annotations}
        encoding = self.image_processor(images=images, annotations=annotations, return_tensors="pt")
        pixel_values = encoding["pixel_values"].squeeze()
        target = encoding["labels"][0]

        return pixel_values, target # pixel_values: image_processor에서 처리한 이미지 결과, target: image_processor에서 처리한 라벨 결과


TRAIN_DATASET = CocoDetection(
    dataset_directory_path=f"{TRAIN_DIRECTORY}",
    image_directory_path=f"{TRAIN_DIRECTORY}//data",
    image_processor=image_processor,
    train=True)
VAL_DATASET = CocoDetection(
    dataset_directory_path=f"{VAL_DIRECTORY}",
    image_directory_path=f"{VAL_DIRECTORY}//data",
    image_processor=image_processor,
    train=False)
TEST_DATASET = CocoDetection(
    dataset_directory_path=f"{TEST_DIRECTORY}",
    image_directory_path=f"{TEST_DIRECTORY}//data",
    image_processor=image_processor,
    train=False)

print("Number of training examples:", len(TRAIN_DATASET))
print("Number of validation examples:", len(VAL_DATASET))
print("Number of test examples:", len(TEST_DATASET))
# Out:
# loading annotations into memory...
# Done (t=0.25s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.12s)
# creating index...
# index created!
# Number of training examples: 23323
# Number of validation examples: 10654
# Number of test examples: 3901

# %% [markdown]
# # Visualize Data Entry

# %%
import random
import cv2
import numpy as np
import supervision as sv


# select random image
image_ids = TRAIN_DATASET.coco.getImgIds()
image_id = random.choice(image_ids)
print('Image #{}'.format(image_id))

# load image and annotatons 
image = TRAIN_DATASET.coco.loadImgs(image_id)[0]
annotations = TRAIN_DATASET.coco.imgToAnns[image_id]
image_path = os.path.join(TRAIN_DATASET.root, image['file_name'])
image = cv2.imread(image_path)

# annotate
detections = sv.Detections.from_coco_annotations(coco_annotation=annotations)

categories = TRAIN_DATASET.coco.cats
id2label = {k: v['name'] for k,v in categories.items()} # 카테고리 번호와 카테고리 이름을 딕셔너리 형태로 저장

labels = [  # annotation의 카테고리 이름 저장
    f"{id2label[class_id]}" 
    for _, _, class_id, _ 
    in detections
]

box_annotator = sv.BoxAnnotator()
frame = box_annotator.annotate(scene=image, detections=detections, labels=labels)

# %matplotlib inline  
sv.show_frame_in_notebook(image, (16, 16))
# Out:
# Image #11477

# %%
from torch.utils.data import DataLoader

def collate_fn(batch):
    # DETR 논문에서 훈련 중 다양한 이미지 크기를 사용했기 때문에 직접 배치를 구성할 수 없음. 
    # 가장 큰 해상도(min:800, max: 1333)로 이미지를 패딩하고 실제 픽셀과 패딩 픽셀을 구분하는 이진 pixel_mask를 생성.
 
    pixel_values = [item[0] for item in batch]
    encoding = image_processor.pad(pixel_values, return_tensors="pt")
    labels = [item[1] for item in batch]
    return {
        'pixel_values': encoding['pixel_values'],
        'pixel_mask': encoding['pixel_mask'],
        'labels': labels
    }

TRAIN_DATALOADER = DataLoader(dataset=TRAIN_DATASET, collate_fn=collate_fn, batch_size=4, num_workers=8, shuffle=True, pin_memory=True)
VAL_DATALOADER = DataLoader(dataset=VAL_DATASET, collate_fn=collate_fn, batch_size=4, num_workers=8, pin_memory=True)
TEST_DATALOADER = DataLoader(dataset=TEST_DATASET, collate_fn=collate_fn, batch_size=2, pin_memory=True)

# %% [markdown]
# # Train Model with Pytorch Lightning

# %%
import pytorch_lightning as pl
from transformers import DetrForObjectDetection, DetrForObjectDetection
import torch
import wandb



class Detr(pl.LightningModule):

    def __init__(self, lr=1e-4, lr_backbone=1e-5, weight_decay=1e-4):
        super().__init__()
        self.model = DetrForObjectDetection.from_pretrained(    # huggingface 모델 라이브러리에서 pretrained 모델 불러오기
            pretrained_model_name_or_path=CHECKPOINT,
            revision = 'no_timm',
            num_labels=len(id2label),   # 인식할 카테고리 갯수
            ignore_mismatched_sizes=True    # pretrained 된 모델과 사이즈가 달라도 오류 무시
        )
        
        self.save_hyperparameters
        
        # 특정 레이어 Freeze
            # backbone
        for param in self.model.model.backbone.parameters():
            param.requires_grad = False

            # attention heads
        for layer in self.model.model.encoder.layers:   # encoder의 self-attention-heads
            for param in layer.self_attn.parameters():
                param.requires_grad = False

        for layer in self.model.model.decoder.layers:   # decoder의 self-attention-heads & encoder-attention-heads
            for param in layer.self_attn.parameters():
                param.requires_grad = False
            for param in layer.encoder_attn.parameters():
                param.requires_grad = False

            # Encoder와 Decoder의 각 초반 3개 layers
        # for layer in self.model.model.encoder.layers[:3]: # First 3 layers of encoder
        #     for param in layer.parameters():
        #         param.requires_grad = False
        
        # for layer in self.model.model.decoder.layers[:3]: # First 3 layers of decoder
        #     for param in layer.parameters():
        #         param.requires_grad = False

        self.lr = lr
        self.lr_backbone = lr_backbone
        self.weight_decay = weight_decay

    def forward(self, pixel_values, pixel_mask):
        return self.model(pixel_values=pixel_values, pixel_mask=pixel_mask)

    # train, validation, test loss 계산에 공통적으로 필요한 처리 
    def common_step(self, batch, batch_idx):
        pixel_values = batch["pixel_values"]
        pixel_mask = batch["pixel_mask"]
        labels = [{k: v.to(self.device) for k, v in t.items()} for t in batch["labels"]]

        outputs = self.model(pixel_values=pixel_values, pixel_mask=pixel_mask, labels=labels)

        loss = outputs.loss
        loss_dict = outputs.loss_dict
  
        return loss, loss_dict

        # training loss 계산
    def training_step(self, batch, batch_idx):
        loss, loss_dict = self.common_step(batch, batch_idx)
        # logs metrics for each training_step, and the average across the epoch
        self.log("training_loss", loss, on_step=True, on_epoch=True, logger=True)
        for k,v in loss_dict.items():
            self.log("train_" + k, v.item())
        return loss
        
        # validation loss 계산
    def validation_step(self, batch, batch_idx):    
        loss, loss_dict = self.common_step(batch, batch_idx)
        self.log("validation/loss", loss,on_step=True, on_epoch=True, logger=True)
        for k, v in loss_dict.items():
            self.log("validation_" + k, v.item())
        return loss

    def test_step(self, batch, batch_idx):
        loss, loss_dict = self.common_step(batch, batch_idx)
        # logs metrics for each training_step, and the average across the epoch
        self.log("test_loss", loss, on_step=True, on_epoch=True, logger=True)
        for k,v in loss_dict.items():
            self.log("test_" + k, v.item())
        return loss

    def configure_optimizers(self):
        # DETR 논문에서 backbone과 나머지 layer에 다른 학습률을 사용한 것을 코드로 구현 (공부목적)
        param_dicts = [
            {
                "params": [p for n, p in self.named_parameters() if "backbone" not in n and p.requires_grad]},  # backbone 아닌경우 learning rate = lr
            {
                "params": [p for n, p in self.named_parameters() if "backbone" in n and p.requires_grad],   # backbone일 경우 learning rate = lr_backbone
                "lr": self.lr_backbone,
            },
        ]
        return torch.optim.AdamW(param_dicts, lr=self.lr, weight_decay=self.weight_decay)

    def train_dataloader(self):
        return TRAIN_DATALOADER

    def val_dataloader(self):
        return VAL_DATALOADER

    def test_dataloader(self):
        return TEST_DATALOADER

# %% [markdown]
# **Start WanDB Logger**

# %%
from pytorch_lightning.loggers import WandbLogger
# Weights and Biases Logger 설정
wandb_logger = WandbLogger(name="run7 - 30epochs", project="YouReco-DeTR", save_dir="/mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR", log_model=True)

# %%
# 학습할 모델 설정
model = Detr(lr=1e-4, lr_backbone=1e-5, weight_decay=1e-4)

# Layer Freeze 확인
for name, param in model.model.model.named_parameters():
    print(f"{name}: requires_grad={param.requires_grad}")

# 모델 GPU에 로드
model.to(DEVICE)
# Out:
# Some weights of DetrForObjectDetection were not initialized from the model checkpoint at facebook/detr-resnet-50 and are newly initialized because the shapes did not match:
# - class_labels_classifier.weight: found shape torch.Size([92, 256]) in the checkpoint and torch.Size([11, 256]) in the model instantiated
# - class_labels_classifier.bias: found shape torch.Size([92]) in the checkpoint and torch.Size([11]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# backbone.conv_encoder.model.embedder.embedder.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.0.shortcut.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.0.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.0.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.0.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.1.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.1.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.1.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.2.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.2.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.0.layers.2.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.0.shortcut.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.0.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.0.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.0.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.1.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.1.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.1.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.2.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.2.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.2.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.3.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.3.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.1.layers.3.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.0.shortcut.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.0.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.0.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.0.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.1.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.1.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.1.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.2.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.2.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.2.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.3.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.3.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.3.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.4.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.4.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.4.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.5.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.5.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.2.layers.5.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.0.shortcut.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.0.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.0.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.0.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.1.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.1.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.1.layer.2.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.2.layer.0.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.2.layer.1.convolution.weight: requires_grad=False
# backbone.conv_encoder.model.encoder.stages.3.layers.2.layer.2.convolution.weight: requires_grad=False
# input_projection.weight: requires_grad=True
# input_projection.bias: requires_grad=True
# query_position_embeddings.weight: requires_grad=True
# encoder.layers.0.self_attn.k_proj.weight: requires_grad=False
# encoder.layers.0.self_attn.k_proj.bias: requires_grad=False
# encoder.layers.0.self_attn.v_proj.weight: requires_grad=False
# encoder.layers.0.self_attn.v_proj.bias: requires_grad=False
# encoder.layers.0.self_attn.q_proj.weight: requires_grad=False
# encoder.layers.0.self_attn.q_proj.bias: requires_grad=False
# encoder.layers.0.self_attn.out_proj.weight: requires_grad=False
# encoder.layers.0.self_attn.out_proj.bias: requires_grad=False
# encoder.layers.0.self_attn_layer_norm.weight: requires_grad=True
# encoder.layers.0.self_attn_layer_norm.bias: requires_grad=True
# encoder.layers.0.fc1.weight: requires_grad=True
# encoder.layers.0.fc1.bias: requires_grad=True
# encoder.layers.0.fc2.weight: requires_grad=True
# encoder.layers.0.fc2.bias: requires_grad=True
# encoder.layers.0.final_layer_norm.weight: requires_grad=True
# encoder.layers.0.final_layer_norm.bias: requires_grad=True
# encoder.layers.1.self_attn.k_proj.weight: requires_grad=False
# encoder.layers.1.self_attn.k_proj.bias: requires_grad=False
# encoder.layers.1.self_attn.v_proj.weight: requires_grad=False
# encoder.layers.1.self_attn.v_proj.bias: requires_grad=False
# encoder.layers.1.self_attn.q_proj.weight: requires_grad=False
# encoder.layers.1.self_attn.q_proj.bias: requires_grad=False
# encoder.layers.1.self_attn.out_proj.weight: requires_grad=False
# encoder.layers.1.self_attn.out_proj.bias: requires_grad=False
# encoder.layers.1.self_attn_layer_norm.weight: requires_grad=True
# encoder.layers.1.self_attn_layer_norm.bias: requires_grad=True
# encoder.layers.1.fc1.weight: requires_grad=True
# encoder.layers.1.fc1.bias: requires_grad=True
# encoder.layers.1.fc2.weight: requires_grad=True
# encoder.layers.1.fc2.bias: requires_grad=True
# encoder.layers.1.final_layer_norm.weight: requires_grad=True
# encoder.layers.1.final_layer_norm.bias: requires_grad=True
# encoder.layers.2.self_attn.k_proj.weight: requires_grad=False
# encoder.layers.2.self_attn.k_proj.bias: requires_grad=False
# encoder.layers.2.self_attn.v_proj.weight: requires_grad=False
# encoder.layers.2.self_attn.v_proj.bias: requires_grad=False
# encoder.layers.2.self_attn.q_proj.weight: requires_grad=False
# encoder.layers.2.self_attn.q_proj.bias: requires_grad=False
# encoder.layers.2.self_attn.out_proj.weight: requires_grad=False
# encoder.layers.2.self_attn.out_proj.bias: requires_grad=False
# encoder.layers.2.self_attn_layer_norm.weight: requires_grad=True
# encoder.layers.2.self_attn_layer_norm.bias: requires_grad=True
# encoder.layers.2.fc1.weight: requires_grad=True
# encoder.layers.2.fc1.bias: requires_grad=True
# encoder.layers.2.fc2.weight: requires_grad=True
# encoder.layers.2.fc2.bias: requires_grad=True
# encoder.layers.2.final_layer_norm.weight: requires_grad=True
# encoder.layers.2.final_layer_norm.bias: requires_grad=True
# encoder.layers.3.self_attn.k_proj.weight: requires_grad=False
# encoder.layers.3.self_attn.k_proj.bias: requires_grad=False
# encoder.layers.3.self_attn.v_proj.weight: requires_grad=False
# encoder.layers.3.self_attn.v_proj.bias: requires_grad=False
# encoder.layers.3.self_attn.q_proj.weight: requires_grad=False
# encoder.layers.3.self_attn.q_proj.bias: requires_grad=False
# encoder.layers.3.self_attn.out_proj.weight: requires_grad=False
# encoder.layers.3.self_attn.out_proj.bias: requires_grad=False
# encoder.layers.3.self_attn_layer_norm.weight: requires_grad=True
# encoder.layers.3.self_attn_layer_norm.bias: requires_grad=True
# encoder.layers.3.fc1.weight: requires_grad=True
# encoder.layers.3.fc1.bias: requires_grad=True
# encoder.layers.3.fc2.weight: requires_grad=True
# encoder.layers.3.fc2.bias: requires_grad=True
# encoder.layers.3.final_layer_norm.weight: requires_grad=True
# encoder.layers.3.final_layer_norm.bias: requires_grad=True
# encoder.layers.4.self_attn.k_proj.weight: requires_grad=False
# encoder.layers.4.self_attn.k_proj.bias: requires_grad=False
# encoder.layers.4.self_attn.v_proj.weight: requires_grad=False
# encoder.layers.4.self_attn.v_proj.bias: requires_grad=False
# encoder.layers.4.self_attn.q_proj.weight: requires_grad=False
# encoder.layers.4.self_attn.q_proj.bias: requires_grad=False
# encoder.layers.4.self_attn.out_proj.weight: requires_grad=False
# encoder.layers.4.self_attn.out_proj.bias: requires_grad=False
# encoder.layers.4.self_attn_layer_norm.weight: requires_grad=True
# encoder.layers.4.self_attn_layer_norm.bias: requires_grad=True
# encoder.layers.4.fc1.weight: requires_grad=True
# encoder.layers.4.fc1.bias: requires_grad=True
# encoder.layers.4.fc2.weight: requires_grad=True
# encoder.layers.4.fc2.bias: requires_grad=True
# encoder.layers.4.final_layer_norm.weight: requires_grad=True
# encoder.layers.4.final_layer_norm.bias: requires_grad=True
# encoder.layers.5.self_attn.k_proj.weight: requires_grad=False
# encoder.layers.5.self_attn.k_proj.bias: requires_grad=False
# encoder.layers.5.self_attn.v_proj.weight: requires_grad=False
# encoder.layers.5.self_attn.v_proj.bias: requires_grad=False
# encoder.layers.5.self_attn.q_proj.weight: requires_grad=False
# encoder.layers.5.self_attn.q_proj.bias: requires_grad=False
# encoder.layers.5.self_attn.out_proj.weight: requires_grad=False
# encoder.layers.5.self_attn.out_proj.bias: requires_grad=False
# encoder.layers.5.self_attn_layer_norm.weight: requires_grad=True
# encoder.layers.5.self_attn_layer_norm.bias: requires_grad=True
# encoder.layers.5.fc1.weight: requires_grad=True
# encoder.layers.5.fc1.bias: requires_grad=True
# encoder.layers.5.fc2.weight: requires_grad=True
# encoder.layers.5.fc2.bias: requires_grad=True
# encoder.layers.5.final_layer_norm.weight: requires_grad=True
# encoder.layers.5.final_layer_norm.bias: requires_grad=True
# decoder.layers.0.self_attn.k_proj.weight: requires_grad=False
# decoder.layers.0.self_attn.k_proj.bias: requires_grad=False
# decoder.layers.0.self_attn.v_proj.weight: requires_grad=False
# decoder.layers.0.self_attn.v_proj.bias: requires_grad=False
# decoder.layers.0.self_attn.q_proj.weight: requires_grad=False
# decoder.layers.0.self_attn.q_proj.bias: requires_grad=False
# decoder.layers.0.self_attn.out_proj.weight: requires_grad=False
# decoder.layers.0.self_attn.out_proj.bias: requires_grad=False
# decoder.layers.0.self_attn_layer_norm.weight: requires_grad=True
# decoder.layers.0.self_attn_layer_norm.bias: requires_grad=True
# decoder.layers.0.encoder_attn.k_proj.weight: requires_grad=False
# decoder.layers.0.encoder_attn.k_proj.bias: requires_grad=False
# decoder.layers.0.encoder_attn.v_proj.weight: requires_grad=False
# decoder.layers.0.encoder_attn.v_proj.bias: requires_grad=False
# decoder.layers.0.encoder_attn.q_proj.weight: requires_grad=False
# decoder.layers.0.encoder_attn.q_proj.bias: requires_grad=False
# decoder.layers.0.encoder_attn.out_proj.weight: requires_grad=False
# decoder.layers.0.encoder_attn.out_proj.bias: requires_grad=False
# decoder.layers.0.encoder_attn_layer_norm.weight: requires_grad=True
# decoder.layers.0.encoder_attn_layer_norm.bias: requires_grad=True
# decoder.layers.0.fc1.weight: requires_grad=True
# decoder.layers.0.fc1.bias: requires_grad=True
# decoder.layers.0.fc2.weight: requires_grad=True
# decoder.layers.0.fc2.bias: requires_grad=True
# decoder.layers.0.final_layer_norm.weight: requires_grad=True
# decoder.layers.0.final_layer_norm.bias: requires_grad=True
# decoder.layers.1.self_attn.k_proj.weight: requires_grad=False
# decoder.layers.1.self_attn.k_proj.bias: requires_grad=False
# decoder.layers.1.self_attn.v_proj.weight: requires_grad=False
# decoder.layers.1.self_attn.v_proj.bias: requires_grad=False
# decoder.layers.1.self_attn.q_proj.weight: requires_grad=False
# decoder.layers.1.self_attn.q_proj.bias: requires_grad=False
# decoder.layers.1.self_attn.out_proj.weight: requires_grad=False
# decoder.layers.1.self_attn.out_proj.bias: requires_grad=False
# decoder.layers.1.self_attn_layer_norm.weight: requires_grad=True
# decoder.layers.1.self_attn_layer_norm.bias: requires_grad=True
# decoder.layers.1.encoder_attn.k_proj.weight: requires_grad=False
# decoder.layers.1.encoder_attn.k_proj.bias: requires_grad=False
# decoder.layers.1.encoder_attn.v_proj.weight: requires_grad=False
# decoder.layers.1.encoder_attn.v_proj.bias: requires_grad=False
# decoder.layers.1.encoder_attn.q_proj.weight: requires_grad=False
# decoder.layers.1.encoder_attn.q_proj.bias: requires_grad=False
# decoder.layers.1.encoder_attn.out_proj.weight: requires_grad=False
# decoder.layers.1.encoder_attn.out_proj.bias: requires_grad=False
# decoder.layers.1.encoder_attn_layer_norm.weight: requires_grad=True
# decoder.layers.1.encoder_attn_layer_norm.bias: requires_grad=True
# decoder.layers.1.fc1.weight: requires_grad=True
# decoder.layers.1.fc1.bias: requires_grad=True
# decoder.layers.1.fc2.weight: requires_grad=True
# decoder.layers.1.fc2.bias: requires_grad=True
# decoder.layers.1.final_layer_norm.weight: requires_grad=True
# decoder.layers.1.final_layer_norm.bias: requires_grad=True
# decoder.layers.2.self_attn.k_proj.weight: requires_grad=False
# decoder.layers.2.self_attn.k_proj.bias: requires_grad=False
# decoder.layers.2.self_attn.v_proj.weight: requires_grad=False
# decoder.layers.2.self_attn.v_proj.bias: requires_grad=False
# decoder.layers.2.self_attn.q_proj.weight: requires_grad=False
# decoder.layers.2.self_attn.q_proj.bias: requires_grad=False
# decoder.layers.2.self_attn.out_proj.weight: requires_grad=False
# decoder.layers.2.self_attn.out_proj.bias: requires_grad=False
# decoder.layers.2.self_attn_layer_norm.weight: requires_grad=True
# decoder.layers.2.self_attn_layer_norm.bias: requires_grad=True
# decoder.layers.2.encoder_attn.k_proj.weight: requires_grad=False
# decoder.layers.2.encoder_attn.k_proj.bias: requires_grad=False
# decoder.layers.2.encoder_attn.v_proj.weight: requires_grad=False
# decoder.layers.2.encoder_attn.v_proj.bias: requires_grad=False
# decoder.layers.2.encoder_attn.q_proj.weight: requires_grad=False
# decoder.layers.2.encoder_attn.q_proj.bias: requires_grad=False
# decoder.layers.2.encoder_attn.out_proj.weight: requires_grad=False
# decoder.layers.2.encoder_attn.out_proj.bias: requires_grad=False
# decoder.layers.2.encoder_attn_layer_norm.weight: requires_grad=True
# decoder.layers.2.encoder_attn_layer_norm.bias: requires_grad=True
# decoder.layers.2.fc1.weight: requires_grad=True
# decoder.layers.2.fc1.bias: requires_grad=True
# decoder.layers.2.fc2.weight: requires_grad=True
# decoder.layers.2.fc2.bias: requires_grad=True
# decoder.layers.2.final_layer_norm.weight: requires_grad=True
# decoder.layers.2.final_layer_norm.bias: requires_grad=True
# decoder.layers.3.self_attn.k_proj.weight: requires_grad=False
# decoder.layers.3.self_attn.k_proj.bias: requires_grad=False
# decoder.layers.3.self_attn.v_proj.weight: requires_grad=False
# decoder.layers.3.self_attn.v_proj.bias: requires_grad=False
# decoder.layers.3.self_attn.q_proj.weight: requires_grad=False
# decoder.layers.3.self_attn.q_proj.bias: requires_grad=False
# decoder.layers.3.self_attn.out_proj.weight: requires_grad=False
# decoder.layers.3.self_attn.out_proj.bias: requires_grad=False
# decoder.layers.3.self_attn_layer_norm.weight: requires_grad=True
# decoder.layers.3.self_attn_layer_norm.bias: requires_grad=True
# decoder.layers.3.encoder_attn.k_proj.weight: requires_grad=False
# decoder.layers.3.encoder_attn.k_proj.bias: requires_grad=False
# decoder.layers.3.encoder_attn.v_proj.weight: requires_grad=False
# decoder.layers.3.encoder_attn.v_proj.bias: requires_grad=False
# decoder.layers.3.encoder_attn.q_proj.weight: requires_grad=False
# decoder.layers.3.encoder_attn.q_proj.bias: requires_grad=False
# decoder.layers.3.encoder_attn.out_proj.weight: requires_grad=False
# decoder.layers.3.encoder_attn.out_proj.bias: requires_grad=False
# decoder.layers.3.encoder_attn_layer_norm.weight: requires_grad=True
# decoder.layers.3.encoder_attn_layer_norm.bias: requires_grad=True
# decoder.layers.3.fc1.weight: requires_grad=True
# decoder.layers.3.fc1.bias: requires_grad=True
# decoder.layers.3.fc2.weight: requires_grad=True
# decoder.layers.3.fc2.bias: requires_grad=True
# decoder.layers.3.final_layer_norm.weight: requires_grad=True
# decoder.layers.3.final_layer_norm.bias: requires_grad=True
# decoder.layers.4.self_attn.k_proj.weight: requires_grad=False
# decoder.layers.4.self_attn.k_proj.bias: requires_grad=False
# decoder.layers.4.self_attn.v_proj.weight: requires_grad=False
# decoder.layers.4.self_attn.v_proj.bias: requires_grad=False
# decoder.layers.4.self_attn.q_proj.weight: requires_grad=False
# decoder.layers.4.self_attn.q_proj.bias: requires_grad=False
# decoder.layers.4.self_attn.out_proj.weight: requires_grad=False
# decoder.layers.4.self_attn.out_proj.bias: requires_grad=False
# decoder.layers.4.self_attn_layer_norm.weight: requires_grad=True
# decoder.layers.4.self_attn_layer_norm.bias: requires_grad=True
# decoder.layers.4.encoder_attn.k_proj.weight: requires_grad=False
# decoder.layers.4.encoder_attn.k_proj.bias: requires_grad=False
# decoder.layers.4.encoder_attn.v_proj.weight: requires_grad=False
# decoder.layers.4.encoder_attn.v_proj.bias: requires_grad=False
# decoder.layers.4.encoder_attn.q_proj.weight: requires_grad=False
# decoder.layers.4.encoder_attn.q_proj.bias: requires_grad=False
# decoder.layers.4.encoder_attn.out_proj.weight: requires_grad=False
# decoder.layers.4.encoder_attn.out_proj.bias: requires_grad=False
# decoder.layers.4.encoder_attn_layer_norm.weight: requires_grad=True
# decoder.layers.4.encoder_attn_layer_norm.bias: requires_grad=True
# decoder.layers.4.fc1.weight: requires_grad=True
# decoder.layers.4.fc1.bias: requires_grad=True
# decoder.layers.4.fc2.weight: requires_grad=True
# decoder.layers.4.fc2.bias: requires_grad=True
# decoder.layers.4.final_layer_norm.weight: requires_grad=True
# decoder.layers.4.final_layer_norm.bias: requires_grad=True
# decoder.layers.5.self_attn.k_proj.weight: requires_grad=False
# decoder.layers.5.self_attn.k_proj.bias: requires_grad=False
# decoder.layers.5.self_attn.v_proj.weight: requires_grad=False
# decoder.layers.5.self_attn.v_proj.bias: requires_grad=False
# decoder.layers.5.self_attn.q_proj.weight: requires_grad=False
# decoder.layers.5.self_attn.q_proj.bias: requires_grad=False
# decoder.layers.5.self_attn.out_proj.weight: requires_grad=False
# decoder.layers.5.self_attn.out_proj.bias: requires_grad=False
# decoder.layers.5.self_attn_layer_norm.weight: requires_grad=True
# decoder.layers.5.self_attn_layer_norm.bias: requires_grad=True
# decoder.layers.5.encoder_attn.k_proj.weight: requires_grad=False
# decoder.layers.5.encoder_attn.k_proj.bias: requires_grad=False
# decoder.layers.5.encoder_attn.v_proj.weight: requires_grad=False
# decoder.layers.5.encoder_attn.v_proj.bias: requires_grad=False
# decoder.layers.5.encoder_attn.q_proj.weight: requires_grad=False
# decoder.layers.5.encoder_attn.q_proj.bias: requires_grad=False
# decoder.layers.5.encoder_attn.out_proj.weight: requires_grad=False
# decoder.layers.5.encoder_attn.out_proj.bias: requires_grad=False
# decoder.layers.5.encoder_attn_layer_norm.weight: requires_grad=True
# decoder.layers.5.encoder_attn_layer_norm.bias: requires_grad=True
# decoder.layers.5.fc1.weight: requires_grad=True
# decoder.layers.5.fc1.bias: requires_grad=True
# decoder.layers.5.fc2.weight: requires_grad=True
# decoder.layers.5.fc2.bias: requires_grad=True
# decoder.layers.5.final_layer_norm.weight: requires_grad=True
# decoder.layers.5.final_layer_norm.bias: requires_grad=True
# decoder.layernorm.weight: requires_grad=True
# decoder.layernorm.bias: requires_grad=True
# Detr(
#   (model): DetrForObjectDetection(
#     (model): DetrModel(
#       (backbone): DetrConvModel(
#         (conv_encoder): DetrConvEncoder(
#           (model): ResNetBackbone(
#             (embedder): ResNetEmbeddings(
#               (embedder): ResNetConvLayer(
#                 (convolution): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#                 (normalization): DetrFrozenBatchNorm2d()
#                 (activation): ReLU()
#               )
#               (pooler): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#             )
#             (encoder): ResNetEncoder(
#               (stages): ModuleList(
#                 (0): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#                 (1): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (3): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#                 (2): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (3): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (4): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (5): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#                 (3): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (position_embedding): DetrSinePositionEmbedding()
#       )
#       (input_projection): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       (query_position_embeddings): Embedding(100, 256)
#       (encoder): DetrEncoder(
#         (layers): ModuleList(
#           (0-5): 6 x DetrEncoderLayer(
#             (self_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (activation_fn): ReLU()
#             (fc1): Linear(in_features=256, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (decoder): DetrDecoder(
#         (layers): ModuleList(
#           (0-5): 6 x DetrDecoderLayer(
#             (self_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=256, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (class_labels_classifier): Linear(in_features=256, out_features=11, bias=True)
#     (bbox_predictor): DetrMLPPredictionHead(
#       (layers): ModuleList(
#         (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         (2): Linear(in_features=256, out_features=4, bias=True)
#       )
#     )
#   )
# )

# %%
from pytorch_lightning import Trainer
import wandb


# Weights and Biases Logger 설정
run = wandb.init(dir="/mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR",
                 project="YouReco-DeTR",
                 entity="jhk01618",
                 name="run7 - 30epochs",
                 resume= True,
                 reinit= True,
                 config={"epochs":30, "batch_size":4,"num_workers":8},
                 settings=wandb.Settings(start_method="fork"),
                 )
wandb.watch(model)

# GPU precision 설정
torch.set_float32_matmul_precision('medium')

# settings
MAX_EPOCHS = 30

# 모델 학습
trainer = Trainer(devices=1, accelerator="gpu", max_epochs=MAX_EPOCHS, gradient_clip_val=0.1, logger = wandb_logger)

trainer.fit(model, ckpt_path="/mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR/YouReco-DeTR/asdjkyk8/checkpoints/epoch=22-step=134113.ckpt")
run.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jhk01618. Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112385022221992, max=1.0…
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR/wandb/run-20231219_173333-tg8yq5o6</code>
# Syncing run <strong><a href='https://wandb.ai/jhk01618/YouReco-DeTR/runs/tg8yq5o6' target="_blank">run7 - 30epochs</a></strong> to <a href='https://wandb.ai/jhk01618/YouReco-DeTR' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jhk01618/YouReco-DeTR' target="_blank">https://wandb.ai/jhk01618/YouReco-DeTR</a>
#  View run at <a href='https://wandb.ai/jhk01618/YouReco-DeTR/runs/tg8yq5o6' target="_blank">https://wandb.ai/jhk01618/YouReco-DeTR/runs/tg8yq5o6</a>
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages/pytorch_lightning/loggers/wandb.py:389: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# Restoring states from the checkpoint path at /mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR/YouReco-DeTR/asdjkyk8/checkpoints/epoch=22-step=134113.ckpt
# /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:347: The dirpath has changed from '/mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR/YouReco-DeTR/asdjkyk8/checkpoints' to '/mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR/YouReco-DeTR/tg8yq5o6/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                   | Params
# -------------------------------------------------
# 0 | model | DetrForObjectDetection | 41.5 M
# -------------------------------------------------
# 13.3 M    Trainable params
# 28.2 M    Non-trainable params
# 41.5 M    Total params
# 166.016   Total estimated model params size (MB)
# Restored all states from the checkpoint at /mnt/c/Users/jhk16/PycharmProjects/Wise_Ad-/personal/JinhyunKim/Detection/YouReco_DeTR/YouReco-DeTR/asdjkyk8/checkpoints/epoch=22-step=134113.ckpt
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Training: |          | 0/? [00:00<?, ?it/s]
# wandb: Network error (ReadTimeout), entering retry loop.
# /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/jhk16/miniconda3/envs/huggingface/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.

# %%
import gc
import wandb
import torch


# Logger 종료 및 CUDA 캐시 메모리 지우기
wandb.finish()
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Fine-tuned 된 모델로부터 COCO Evaluation Metrics 검출

# %%
# DeTR post_processed_output으로부터의 bbox 좌표를 COCO Dataset 형태로 변형 ([x_min, y_min, x_max, y_max] -> [x1, y1, w, h])
def convert_to_xywh(boxes):
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    return torch.stack((xmin, ymin, xmax - xmin, ymax - ymin), dim=1)

# COCO results에 prediction 결과 저장
def prepare_for_coco_detection(predictions):
    coco_results = []
    for original_id, prediction in predictions.items():
        if len(prediction) == 0:
            continue

        boxes = prediction["boxes"]
        boxes = convert_to_xywh(boxes).tolist()
        scores = prediction["scores"].tolist()
        labels = prediction["labels"].tolist()

        coco_results.extend(
            [
                {
                    "image_id": original_id,
                    "category_id": labels[k],
                    "bbox": box,
                    "score": scores[k],
                }
                for k, box in enumerate(boxes)
            ]
        )
    return coco_results

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Detr(
#   (model): DetrForObjectDetection(
#     (model): DetrModel(
#       (backbone): DetrConvModel(
#         (conv_encoder): DetrConvEncoder(
#           (model): ResNetBackbone(
#             (embedder): ResNetEmbeddings(
#               (embedder): ResNetConvLayer(
#                 (convolution): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#                 (normalization): DetrFrozenBatchNorm2d()
#                 (activation): ReLU()
#               )
#               (pooler): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#             )
#             (encoder): ResNetEncoder(
#               (stages): ModuleList(
#                 (0): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#                 (1): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (3): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#                 (2): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (3): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (4): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (5): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#                 (3): ResNetStage(
#                   (layers): Sequential(
#                     (0): ResNetBottleNeckLayer(
#                       (shortcut): ResNetShortCut(
#                         (convolution): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                         (normalization): DetrFrozenBatchNorm2d()
#                       )
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (1): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                     (2): ResNetBottleNeckLayer(
#                       (shortcut): Identity()
#                       (layer): Sequential(
#                         (0): ResNetConvLayer(
#                           (convolution): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (1): ResNetConvLayer(
#                           (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): ReLU()
#                         )
#                         (2): ResNetConvLayer(
#                           (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                           (normalization): DetrFrozenBatchNorm2d()
#                           (activation): Identity()
#                         )
#                       )
#                       (activation): ReLU()
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (position_embedding): DetrSinePositionEmbedding()
#       )
#       (input_projection): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       (query_position_embeddings): Embedding(100, 256)
#       (encoder): DetrEncoder(
#         (layers): ModuleList(
#           (0-5): 6 x DetrEncoderLayer(
#             (self_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (activation_fn): ReLU()
#             (fc1): Linear(in_features=256, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (decoder): DetrDecoder(
#         (layers): ModuleList(
#           (0-5): 6 x DetrDecoderLayer(
#             (self_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=256, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (class_labels_classifier): Linear(in_features=256, out_features=11, bias=True)
#     (bbox_predictor): DetrMLPPredictionHead(
#       (layers): ModuleList(
#         (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         (2): Linear(in_features=256, out_features=4, bias=True)
#       )
#     )
#   )
# )

# %%
from coco_eval import CocoEvaluator
from tqdm.notebook import tqdm
import numpy as np

# COCO Evluator를 TEST_DATASET의 ground truth에 대해 초기화
evaluator = CocoEvaluator(coco_gt=TEST_DATASET.coco, iou_types=["bbox"])

print("Running evaluation...")

# TEST_DATALOADER를 통해 data batch를 순회
for idx, batch in enumerate(tqdm(TEST_DATALOADER)):
    pixel_values = batch["pixel_values"].to(device)
    pixel_mask = batch["pixel_mask"].to(device)
    labels = [{k: v.to(device) for k, v in t.items()} for t in batch["labels"]] # DETR 형태, resized + normalized

    # 순전파
    with torch.no_grad():
      outputs = model(pixel_values=pixel_values, pixel_mask=pixel_mask)

    # 배치의 각 사진에 대한 결과를 저장
    orig_target_sizes = torch.stack([target["orig_size"] for target in labels], dim=0)
    results = image_processor.post_process_object_detection(outputs, target_sizes=orig_target_sizes, threshold=0)

    # image_id, category_id, bbox and score 를 키로 하는 딕셔너리 형태로 evaluation 진행
    predictions = {target['image_id'].item(): output for target, output in zip(labels, results)}
    predictions = prepare_for_coco_detection(predictions)
    evaluator.update(predictions)

evaluator.synchronize_between_processes()
evaluator.accumulate()
evaluator.summarize()
# Out:
# Running evaluation...
#   0%|          | 0/1222 [00:00<?, ?it/s]
# Accumulating evaluation results...
# DONE (t=1.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.719
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.645
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.869
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.874
