# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
categories_list = pd.read_excel('./category_code.xlsx')

# %%
categories_list
# Out:
#            name  coupang      naver
# 0         강아지간식   118900  100000705
# 1         강아지사료   445725  100000708
# 2        강아지영양제   486318  100008246
# 3         강아지용품   118876  100000697
# 4         고양이사료   445859  100000720
# 5         고양이간식   119402  100000717
# 6        고양이영양제   486331  100008246
# 7         고양이용품   118878  100000698
# 8          건식사료   445726  100000751
# 9     강아지 소프트사료   445727  100000754
# 10     강아지 습식사료   445728  100000756
# 11  강아지 건조/생식사요   445729  100000752
# 12     강아지 화식사료   445730  100000757
# 13       강아지 분유   445731  100000753
# 14        캔/파우치   118975  100000737
# 15          덴탈껌   385001  100000730
# 16      건조간식/육포   385002  100000735
# 17       동결건조간식   385003  100000731
# 18   비스켓/시리얼/쿠키   118974  100000732
# 19        빵/케이크   225064  100000733
# 20           음료   118980  100000736

# %%
categories_list = pd.read_excel('./category_code.xlsx')
naver_code = categories_list.loc[categories_list.name == '건식사료', ['naver']]

# %%
naver_code.shape == (1,1)
# Out:
# True

# %%
int(naver_code.iloc[0,0])
# Out:
# 100000751

# %%
import libs.getUrl as getUrl

# %%
text=  getUrl.getres("https://www.coupang.com/np/categories/118900")
# Out:
# C:\Users\Egn\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.coupang.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<!--[if lte IE 7 ]><html class="lt-ie9 lt-ie8" lang="ko-KR"><![endif]-->\n<!--[if IE 8 ]><html class="lt-ie9" lang="ko-KR"><![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--><html lang="ko-KR"><!--<![endif]-->\n<head>\n    <meta charset="utf-8" />\n    <meta name="google-site-verification" content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" />\n    <meta http-equiv="x-dns-prefetch-control" content="on" />\n    <link rel="dns-prefetch" href="//cart.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupang.com" />\n    <link rel="dns-prefetch" href="//assets2.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//asset1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//private.coupang.com" />\n    <link rel="dns-prefetch" href="//img1a.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//image1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//thumbnail1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//static.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//www.facebook.com" />\n    <link rel="dns-prefetch" href="//www.google.com" />\n    <link rel="dns-prefetch" href="//www.google.co.kr" />\n    <link rel="dns-prefetch" href="//stats.g.doubleclick.net" />\n    <link rel="dns-prefetch" href="//connect.facebook.net" />\n\n    <title>쿠팡!</title>\n    \n    \n\n    \n    \n        \n        \n        \n            <meta property="og:title" content="COUPANG"/>\n            <meta property="og:image" content="//image10.coupangcdn.com/image/mobile/v3/img_fb_like.png"/>\n            <meta property="og:url" content="https://www.coupang.com"/>\n        \n        \n        \n            \n                \n                    <meta property="og:description" content="쿠팡은 로켓배송"/>\n                \n            \n        \n\n        \n\n        \n\n        \n    \n\n<meta property="og:type" content="website"/>\n\n\n    <link rel="shortcut icon" href="//image9.coupangcdn.com/image/coupang/favicon/v2/favicon.ico" type="image/x-icon" />\n    \n    \n        <!--[if lt IE 9]>\n<script src="/resources/20231205153617/np/js/lib/html5/html5.js" type="text/javascript"></script>\n<![endif]-->\n<!--[if lte IE 9]>\n<script src="//asset2.coupangcdn.com/cdnjs/json2/20150503/json2.js" type="text/javascript"></script>\n<![endif]-->\n\n    \n        <link rel="stylesheet" href="/resources/20231205153617/np/css/common.ko-KR.css" type="text/css" />\n        <link rel="stylesheet" href="/resources/20231205153617/np/css/side.css" type="text/css" />\n        \n            <link rel="stylesheet" href="/resources/20231205153617/np/css/list.css" type="text/css" />\n            <link rel="stylesheet" href="/resources/20231205153617/np/css/ddp.css" type="text/css" />\n            <link rel="stylesheet" href="/resources/20231205153617/np/css/productReview.min.css" type="text/css" />\n        \n    \n\n\n    \n    \n    \n    <link rel="stylesheet" href="/resources/20231205153617/np/css/list.ko-KR.css" type="text/css" />\n    <link rel="stylesheet" href="/resources/20231205153617/np/css/todaysection.css" type="text/css" />\n    <link rel="stylesheet" href="/resources/20231205153617/np/css/pdpcollection.ko-KR.css" type="text/css" />\n    <link rel="stylesheet" href="/resources/20231205153617/np/js/modules/cmgComponents/dist/pcPlpBanners.css" type="text/css" />\n\n\n     <style>#coupang-banner span.banner-bg{background:#FFFFFF;border-bottom:1px solid #cac6c3}\n        #coupang-banner span.banner-bg{float:left;width:100%;}\n        #coupang-banner .banner-middle{width:980px;margin:0 auto;}\n        #coupang-banner .banner-middle a{float:left;display: inline-block}</style>\n\n    \n    <script src=\'//asset2.coupangcdn.com/customjs/pacifik/1.5.1/pacifik.polyfill.min.js\' type="text/javascript"></script>\n<script src=\'//asset2.coupangcdn.com/customjs/pacifik/1.5.1/pacifik.min.js\' type="text/javascript"></script>\n<script src=\'/ ...

# %%
def getinfo(string):
    # 주어진 HTML 문자열로부터 상품 정보를 추출하는 함수
    soup = BeautifulSoup(string, 'html5lib')
    ul = soup.find('ul', {'id':'productList'})
    li = soup.findAll('li', {'class':'baby-product renew-badge'})

    for product in li:
        # 썸네일 이미지 추출
        dt_class_image = product.find('dt', {'class':'image'})
        img_src = dt_class_image.find('img').get('src')
        imglist.append(img_src)

        # 상품명 추출
        div_class_name = product.find('div', {'class':'name'})
        name_text = div_class_name.getText()
        namelist.append(name_text)

        # 가격 추출
        strong_class_pricevalue = product.find('strong', {'class':'price-value'})
        price = strong_class_pricevalue.getText()
        pricelist.append(price)

        # 평점 추출 (없는 경우 NA 처리)
        try:
            em_class_rating = product.find('em', {'class':'rating'})
            rating = em_class_rating.getText()
            ratinglist.append(rating)
        except:
            ratinglist.append(pd.NA)

        # 리뷰 수 추출 (없는 경우 NA 처리)
        try:
            span_class_ratingtotalcount = product.find('span', {'class':'rating-total-count'})
            review_cnt = span_class_ratingtotalcount.getText()
            reviewlist.append(review_cnt)
        except:
            reviewlist.append(pd.NA)

        # 상품 URL 추출
        a_class_baby_product_link = product.find('a', {'class':'baby-product-link'})
        href = a_class_baby_product_link.get('href')
        link = f'https://coupang.com' + href
        linklist.append(link)

# %%
text=  getUrl.getres('https://www.coupang.com/np/categories/118900/?page=1')
# Out:
# C:\Users\Egn\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.coupang.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<!--[if lte IE 7 ]><html class="lt-ie9 lt-ie8" lang="ko-KR"><![endif]-->\n<!--[if IE 8 ]><html class="lt-ie9" lang="ko-KR"><![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--><html lang="ko-KR"><!--<![endif]-->\n<head>\n    <meta charset="utf-8" />\n    <meta name="google-site-verification" content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" />\n    <meta http-equiv="x-dns-prefetch-control" content="on" />\n    <link rel="dns-prefetch" href="//cart.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupang.com" />\n    <link rel="dns-prefetch" href="//assets2.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//asset1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//private.coupang.com" />\n    <link rel="dns-prefetch" href="//img1a.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//image1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//thumbnail1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//static.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//www.facebook.com" />\n    <link rel="dns-prefetch" href="//www.google.com" />\n    <link rel="dns-prefetch" href="//www.google.co.kr" />\n    <link rel="dns-prefetch" href="//stats.g.doubleclick.net" />\n    <link rel="dns-prefetch" href="//connect.facebook.net" />\n\n    <title>쿠팡!</title>\n    \n    \n\n    \n    \n        \n        \n        \n            <meta property="og:title" content="COUPANG"/>\n            <meta property="og:image" content="//image10.coupangcdn.com/image/mobile/v3/img_fb_like.png"/>\n            <meta property="og:url" content="https://www.coupang.com"/>\n        \n        \n        \n            \n                \n                    <meta property="og:description" content="쿠팡은 로켓배송"/>\n                \n            \n        \n\n        \n\n        \n\n        \n    \n\n<meta property="og:type" content="website"/>\n\n\n    <link rel="shortcut icon" href="//image9.coupangcdn.com/image/coupang/favicon/v2/favicon.ico" type="image/x-icon" />\n    \n    \n        <!--[if lt IE 9]>\n<script src="/resources/20231205153617/np/js/lib/html5/html5.js" type="text/javascript"></script>\n<![endif]-->\n<!--[if lte IE 9]>\n<script src="//asset2.coupangcdn.com/cdnjs/json2/20150503/json2.js" type="text/javascript"></script>\n<![endif]-->\n\n    \n        <link rel="stylesheet" href="/resources/20231205153617/np/css/common.ko-KR.css" type="text/css" />\n        <link rel="stylesheet" href="/resources/20231205153617/np/css/side.css" type="text/css" />\n        \n            <link rel="stylesheet" href="/resources/20231205153617/np/css/list.css" type="text/css" />\n            <link rel="stylesheet" href="/resources/20231205153617/np/css/ddp.css" type="text/css" />\n            <link rel="stylesheet" href="/resources/20231205153617/np/css/productReview.min.css" type="text/css" />\n        \n    \n\n\n    \n    \n    \n    <link rel="stylesheet" href="/resources/20231205153617/np/css/list.ko-KR.css" type="text/css" />\n    <link rel="stylesheet" href="/resources/20231205153617/np/css/todaysection.css" type="text/css" />\n    <link rel="stylesheet" href="/resources/20231205153617/np/css/pdpcollection.ko-KR.css" type="text/css" />\n    <link rel="stylesheet" href="/resources/20231205153617/np/js/modules/cmgComponents/dist/pcPlpBanners.css" type="text/css" />\n\n\n     <style>#coupang-banner span.banner-bg{background:#FFFFFF;border-bottom:1px solid #cac6c3}\n        #coupang-banner span.banner-bg{float:left;width:100%;}\n        #coupang-banner .banner-middle{width:980px;margin:0 auto;}\n        #coupang-banner .banner-middle a{float:left;display: inline-block}</style>\n\n    \n    <script src=\'//asset2.coupangcdn.com/customjs/pacifik/1.5.1/pacifik.polyfill.min.js\' type="text/javascript"></script>\n<script src=\'//asset2.coupangcdn.com/customjs/pacifik/1.5.1/pacifik.min.js\' type="text/javascript"></script>\n<script src=\'/ ...

# %%
import libs.getUrl as getUrl
import libs.createDF as dflib
import libs.importCategories as import_category
import libs.getInfo as getInfo
import libs.downloadimg as downloadimg
import libs.changeExtension as ce

# %%
df_new = dflib.create_df()

# %%
namelist = list()
imglist = list()
pricelist = list()
ratinglist = list()
reviewlist = list()
linklist = list()

# %%
namelist, imglist, pricelist, ratinglist, reviewlist, linklist = getInfo.getinfo(text)

# %%
namelist
# Out:
# ['\n    굿데이 건강한 육포 스틱 강아지간식, 참치, 100g, 3개\n',
#  '\n    네츄럴이엑스 강아지 순수한우 불리 슬라이스, 50g, 1개, 소\n',
#  '\n    뉴트리플랜 동원 홀릭 DHA 소시지 18p, 혼합맛(어육/치즈), 540g, 1개\n',
#  '\n    아미오 소프트큐브 져키, 오리고기, 5개\n',
#  '\n    수제의여왕 강아지 간식, 연어슬라이스, 10개\n',
#  '\n    밥이보약 강아지 하루양갱 건강한 장 사료 28p, 닭+고구마, 224g, 2개\n',
#  '\n    마이독스테이크하우스 강아지 간식 슬라이스, 소고기, 5개\n',
#  '\n    유한양행 더 건강한 뉴트리션바 강아지 영양트릿 30p, 관절, 150g, 2개\n',
#  '\n    베게브랜드 스마트 베게본 덴탈껌 6P, 밀크치킨본, 10개\n',
#  '\n    네츄럴이엑스 강아지 츄 덴탈껌 링 M 30g, 황태, 15개\n',
#  '\n    아미오 애견간식, 칼슘 담은 닭가슴살, 5개\n',
#  '\n    로렌츠 못난이 채소 강아지 껌 21p, 1개\n',
#  '\n    포켄스 강아지 카누들 플러스 필로팩 대용량 덴탈껌 153p, 구강청결, 1040g, 1개\n',
#  '\n    풀무원 반려동물 아미오 건강한 덴탈껌 100g, 그린, 5개\n',
#  '\n    네츄럴이엑스 연어스트립 건조간식 S, 연어맛, 25개\n',
#  '\n    네츄럴이엑스 강아지 불리스틱 간식 소형, 한우, 10개\n',
#  '\n    The 잇츄 옐로우 S 강아지 덴탈껌 43p, 1개, 516g\n',
#  '\n    제로랩스 강아지 미트리스 비건 져키 간식 1kg, 고구마 + 당근 + 클로렐라 혼합맛, 1개\n',
#  '\n    The 잇츄 덴탈 개껌 옐로우 M 34p, 1개\n',
#  '\n    마도로스펫 소고기트릿 반려동물 간식 120g, 우둔살, 1개\n',
#  '\n    굿데이 건강한육포 강아지간식 240g, 오리가슴살말이 황태, 2개\n',
#  '\n    펫츠맘마 강아지 수제간식 슬라이스 200g, 오리, 1개\n',
#  '\n    핏펫 츄잇 강아지 덴탈껌 50g, 산양유, 2개\n',
#  '\n    와그작 반려동물 하루한컵 동결건조 간식 7g x 12p, 두부 + 야채 혼합맛, 84g, 1개\n',
#  '\n    더 잇츄 강아지 덴탈껌 S 79p, 1개\n',
#  '\n    더디앤씨 건강 강아지간식 파우치 100g, 오리백숙, 10개\n',
#  '\n    라무달리 강아지 덴탈츄러스 31p, 연어 + 생선살 혼합맛, 2개\n',
#  '\n    개기월식 강아지 더 채워 대용량 실속형 간식, 1개, 1.1kg, 오리고구마\n',
#  '\n    오랄클리닉 반려동물 치석제거용 덴탈껌 300g, 블루베리, 2개\n',
#  '\n    보호리 강아지 입냄새 예방 뉴트리냠냠 간식 2.65g, 덴탈, 1박스\n',
#  '\n    네츄럴이엑스 황태츄스틱 강아지 덴탈껌 200g, 황태, 2개\n',
#  '\n    굿데이 건강한육포 반려견간식 300g, 건조 닭가슴살 육포, 2개\n',
#  '\n    The 잇츄 강아지 덴탈껌 그린 M 57p, 16g, 1개\n',
#  '\n    굿데이 건강한육포 강아지간식, 닭고기 + 고구마, 1kg, 1개\n',
#  '\n    터키츄 반려견 간식 본타입 S, 칠면조 + 소고기 혼합맛, 40개\n',
#  '\n    핏펫 츄잇 강아지 덴탈껌 50g, 마누카꿀, 2개\n',
#  '\n    The 잇츄 덴탈 개껌 그린 S 43p, 1개\n',
#  '\n    엔젤링 강아지 간식 RING 15g, 칠면조 + 소힘줄 혼합, 40개\n',
#  '\n    아미오 애견간식, 유산균 담은 닭가슴살, 5개\n',
#  '\n    윔지스 밸류백 강아지 덴탈껌 S 360g, 악어, 1개\n',
#  '\n    퍼피프랜드 사각 애견 캔, 소고기, 48개입\n',
#  '\n    청담닥터스랩 데일리솔루션 강아지 덴탈껌, 조인트 웨이트, 1개\n',
#  '\n    굿데이 건강한 육포 강아지 간식 100g, 소프트 소고기맛, 4개\n',
#  '\n    조공 반려동물 미니트릿 65g, 산양유 맛, 2개\n',
#  '\n    네츄럴랩 강아지 건강한 육포 간식 스틱, 연어, 700g, 1개\n',
#  '\n    미라클 강아지 대용량 간식 오리스틱 1kg, 1개, 오리고기\n',
#  '\n    풀무원 반려동물 아미오 건강담은 육포 50g, 칠면조육포맛, 5개\n',
#  '\n    포켄스 카누들 잇몸플러스 강아지 덴탈껌 M, 구강청결, 1040g, 1개\n',
#  '\n    마도로스펫 반려동물 트릿 건조간식, 큰북어, 1개\n',
#  '\n    아나브러쉬 일반 / 납작두상 40p 대용량 치석제거껌 [동물병원정품], 일반두상 40p\n',
#  '\n    풀무원 반려동물 아미오 건강담은 육포 50g, 칠면조육포맛, 10개\n',
#  '\n    포켄스 덴티3페어리 클로로필 덴탈껌, 천연벌꿀, 3개\n',
#  '\n    네츄럴이엑스 한우 불리스틱 강아지간식 초소형, 3g, 30개\n',
#  '\n    굿데이 건강한육포 강아지간식, 오리고기, 1kg, 1개\n',
#  '\n    네츄럴이엑스 한우 불리스틱 강아지간식 중형, 10개\n',
#  '\n    강아지 Think your dog teeth 치킨우유껌 중형 240g 6p, 치킨, 2개\n',
#  '\n    너를위한디저트 강아지캔디 소형견용 M, 닭고기, 5개입\n',
#  '\n    리틀달링 애견간식 사사미, 윙, 10개입\n',
#  '\n    피피픽 덴탈브레드 미니 소형견 덴탈껌 195g, 눈 + 관절 + 피부 건강 혼합맛, 2개\n']

# %%
imglist
# Out:
# ['//thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/rs_quotation_api/a3wqujio/b71573dc3a19463ea0e085a99292d65a.jpg',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/05/25/10/1/abf57372-77a0-458f-bf73-478bcb58b9cd.jpg',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/06/23/17/3/88d1403c-a055-4667-a754-5619594c77c4.jpg',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/product/image/vendoritem/2018/11/20/3275010913/89d6847a-cd6f-475f-aa98-58d1cc5e0e00.jpg',
#  '//thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/1145180077799093-474724e9-7d8e-43c2-8061-3ba19cbf4a31.jpg',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/71ed9c9c-e536-4551-801b-36c068bdfa342996673835487809909.png',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/138360023522561-0f8c1613-7588-4ebc-8c82-c9e33b676480.jpg',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/e3b4bc0c-4fc5-4da6-a931-d55fc0254ee5421885628951892507.png',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/6244146110300295-8550eabf-416d-48bf-ae80-1a48a0e4ac75.jpg',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/9749872373354326-ad1e12da-659f-41a9-b107-088d56361c7a.png',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/product/image/vendoritem/2017/03/27/3073529330/02d5d95c-c087-4b54-ae50-5b5303faaafd.jpg',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2021/12/07/15/9/5ecea9b4-eb4f-458f-a0d7-eca14efd772f.jpg',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/05/25/15/9/a0cc93a0-8e86-463e-ab94-0c377ef774e2.jpg',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/
coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/6806756705258114-510d5c31-13fd-4e07-8337-8d232fc9211b.jpg',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2020/05/20/15/8/395d3e90-b540-4940-bd93-983eb7383a4c.jpg',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/01/19/10/6/0a0a2b3c-999a-467b-9be9-944bceba26a4.png',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/09/05/18/6/42d58558-eca2-496f-8c52-d5cd0e10fd94.jpg',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/rs_quotation_api/1iygffgz/5df1346f9f444782b41fd832f7daae19.jpg',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2021/03/05/13/3/1167a931-8425-4afa-bc64-0fa0f3c2d70f.jpg',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/879233931982489-8134cbc9-5f8a-4244-ba27-0275392001db.JPG',
#  '//thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/11332507404177693-919d098f-3166-4433-b6de-8680cf417f84.jpg',
#  '//thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/1471/9f70e9bb7e69e3df23138ea023345af28ca49a949e08b41854d8f6951a1b.png',
#  '//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/8f729c26-aa60-4c59-9fef-8a73b12b48866557156326343436490.png',
#  '//thumbnail10.coupangcdn.com/thumbnails/remote/230x230ex/image/product/image/vendoritem/2018/11/13/3017876159/675b386c-5b38-4807-b520-a35b9cdeef8f.jpg',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/376116669092706-ed3f027d-a7c2-4af2-863f-78188aa33e90.png',
#  '//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/4411308800885750-7a2dd7d2-9134-450b-aa34-2f849b0eba53.jpg',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2020/02/25/17/1/1f8fee80-eba3-4308-8bb0-ff41eb3f01fc.jpg',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2022/12/28/17/4/7f0e19ca-0124-4988-9c49-b8e4c788b6b5.jpg',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/346700525240650-a7ebd5b1-314e-48cd-a059-a6839be055ad.jpg',
#  '//thumbnail10.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/db6fba46-45a7-46ab-bd1a-bcfd5f40d72d5018988469065894930.png',
#  '//thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/e0a50a3a-ebbd-459f-a94a-adacae69b0e48372716332045079936.png']

# %%
pricelist
# Out:
# ['12,900',
#  '13,750',
#  '13,900',
#  '16,400',
#  '21,800',
#  '22,320',
#  '26,000',
#  '22,100',
#  '17,200',
#  '26,300',
#  '16,010',
#  '28,900',
#  '58,620',
#  '16,400',
#  '28,250',
#  '24,350',
#  '29,410',
#  '26,770',
#  '28,150',
#  '20,500',
#  '25,000',
#  '15,000',
#  '13,400',
#  '19,080',
#  '47,700',
#  '26,500',
#  '26,900',
#  '15,890',
#  '19,600',
#  '45,570',
#  '19,900',
#  '23,000',
#  '39,430',
#  '23,900',
#  '40,900',
#  '13,400',
#  '29,410',
#  '26,100',
#  '16,010',
#  '18,960',
#  '33,800',
#  '12,670',
#  '19,600',
#  '22,300',
#  '17,370',
#  '21,900',
#  '15,960',
#  '45,500',
#  '29,000',
#  '39,000',
#  '27,600',
#  '27,000',
#  '34,250',
#  '24,500',
#  '32,800',
#  '17,000',
#  '16,350',
#  '24,500',
#  '29,000']

# %%
url_list = ['https://www.coupang.com/np/categories/118900/?page=1']

# %%
df_new = dflib.create_df()
namelist, imglist, pricelist, ratinglist, reviewlist, linklist = getInfo.loop_url_getinfo(url_list)
df_tmp = dflib.fill_df(namelist, imglist, pricelist, ratinglist, reviewlist, linklist)
df = dflib.concat_df(df_new, df_tmp)
dflib.to_excel(df, 'test')
# Out:
# C:\Users\Egn\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.coupang.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
df
# Out:
#                                                  Name  \
# 0         \n    네츄럴이엑스 강아지 순수한우 불리 슬라이스, 50g, 1개, 소\n
# 1                      \n    아미오 소프트큐브 져키, 오리고기, 5개\n
# 2   \n    밥이보약 강아지 하루양갱 건강한 장 사료 28p, 닭+고구마, 224g,...
# 3             \n    마이독스테이크하우스 강아지 간식 슬라이스, 소고기, 5개\n
# 4           \n    네츄럴이엑스 강아지 츄 덴탈껌 링 M 30g, 황태, 15개\n
# 5               \n    하림펫푸드 더리얼 저키 강아지 간식, 닭가슴살, 2개\n
# 6   \n    펫러닝 반려동물 촉촉 닭안심 그대로 간식 30g x 30p, 닭가슴살, ...
# 7                    \n    아미오 애견간식, 칼슘 담은 닭가슴살, 5개\n
# 8                    \n    로렌츠 못난이 채소 강아지 껌 21p, 1개\n
# 9   \n    포켄스 강아지 카누들 플러스 필로팩 대용량 덴탈껌 153p, 구강청결, ...
# 10          \n    풀무원 반려동물 아미오 건강한 덴탈껌 100g, 그린, 5개\n
# 11              \n    네츄럴이엑스 연어스트립 건조간식 S, 연어맛, 25개\n
# 12      \n    굿데이 반려견을 위한 건강레시피 져키, 치킨야채, 300g, 3개입\n
# 13             \n    네츄럴이엑스 강아지 불리스틱 간식 소형, 한우, 10개\n
# 14         \n    The 잇츄 옐로우 S 강아지 덴탈껌 43p, 1개, 516g\n
# 15  \n    제로랩스 강아지 미트리스 비건 져키 간식 1kg, 고구마 + 당근 + 클...
# 16    \n    굿데이 반려견을 위한 건강레시피 져키, 닭고기소프트, 300g, 3개입\n
# 17                 \n    The 잇츄 덴탈 개껌 옐로우 M 34p, 1개\n
# 18          \n    마도로스펫 소고기트릿 반려동물 간식 120g, 우둔살, 1개\n
# 19       \n    굿데이 건강한육포 강아지간식 240g, 오리가슴살말이 황태, 2개\n
# 20            \n    펫츠맘마 강아지 수제간식 슬라이스 200g, 오리, 1개\n
# 21                 \n    핏펫 츄잇 강아지 덴탈껌 50g, 산양유, 2개\n
# 22  \n    오랄클리닉 청사과 300g + 블루베리 300g 세트, 청사과, 블루베리...
# 23  \n    와그작 반려동물 하루한컵 동결건조 간식 7g x 12p, 두부 + 야채 ...
# 24       \n    잇츄 반려견 옐로우 덴탈껌 S 10p, 마누카꿀, 12g, 2세트\n
# 25                     \n    더 잇츄 강아지 덴탈껌 S 79p, 1개\n
# 26       \n    라무달리 강아지 덴탈츄러스 31p, 연어 + 생선살 혼합맛, 2개\n
# 27  \n    개기월식 강아지 더 채워 대용량 실속형 간식, 1개, 1.1kg, 오리고...
